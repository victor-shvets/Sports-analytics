# %% [markdown]
# # Analytics
# The notebook will be used to clean, transform, analyze and visualize the data

# %% [markdown]
# # Libraries

# %%
import requests
import pandas as pd
import glob
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
from pandasql import sqldf

# %% [markdown]
# # Load from files

# %%
dfLeaguesCSV = pd.read_csv('raw_data/leagues.csv')
dfTeamsCSV = pd.read_csv('raw_data/teams.csv')

# Initialize empty data frames
dfPlayersCSV = pd.DataFrame()
dfPlayerStatsCSV = pd.DataFrame()

# Load all players files
for name in glob.glob('raw_data/players_*.csv'):
    dfPlayersTemp = pd.read_csv(name)
    dfPlayersCSV = pd.concat([dfPlayersCSV, dfPlayersTemp])
    
# Load all player stats files
for name in glob.glob('raw_data/player_stats_*.csv'):
    dfPlayerStatsTemp = pd.read_csv(name)
    dfPlayerStatsCSV = pd.concat([dfPlayerStatsCSV, dfPlayerStatsTemp])

# %% [markdown]
# # Clean and transform

# %% [markdown]
# ## Join all data frames
# There are several data frames. To perform analysis and build models we need to have just one. Hence we need to combine them.

# %%
# Merge players and player stats data sets
dfFootballCSV = dfPlayersCSV.merge(dfPlayerStatsCSV, left_on=['player_id','league_id','season_id'],\
                             right_on=['player_id','league_id','season_id'])

# Merge the result and teams data sets
dfFootballCSV = dfFootballCSV.merge(dfTeamsCSV, left_on=['team_id','league_id','season_id'],\
                             right_on=['team_id','league_id','season_id'])

# Merge the result and leagues data sets
dfFootballCSV = dfFootballCSV.merge(dfLeaguesCSV, left_on='league_id',\
                             right_on='league_id')
# Out:
#        player_id    player_name  player_firstname       player_lastname  \
# 0            311    O. Karnezis  Orestis Spyridon              Karnezis
# 1           2205    H. Ben Arfa             Hatem              Ben Arfa
# 2          22226    Jérémy Pied            Jérémy                  Pied
# 3         162589      R. Ascone      Rocco Angelo                Ascone
# 4         306862           Bica       José Manuel             Bica Reis
# ...          ...            ...               ...                   ...
# 65875      62960        B. Köse          Bahattin                  Köse
# 65876      62069       Ö. Özcan         Özgür Can                 Özcan
# 65877      62923    E. Taşkıran             Erkan              Taşkıran
# 65878      13142  L. Guaycochea           Luciano            Guaycochea
# 65879     107626  Bruno Mezenga             Bruno  Ferreira Mombra Rosa
#
#        player_age player_birth_date player_birth_place player_birth_country  \
# 0            37.0        1985-07-11             Athina               Greece
# 1            35.0        1987-03-07            Clamart               France
# 2            33.0        1989-02-23           Grenoble               France
# 3            20.0        2003-09-12                NaN               France
# 4            20.0        2003-06-16                NaN             Portugal
# ...           ...               ...                ...                  ...
# 65875        33.0        1990-08-26               Hamm              Germany
# 65876        35.0        1988-04-10            Antalya              Türkiye
# 65877        38.0        1985-04-22              İzmir              Türkiye
# 65878        31.0        1992-04-24         Santa Rosa            Argentina
# 65879        35.0        1988-08-08            Niterói               Brazil
#
#       player_nationality player_height  ...              venue_city  \
# 0                 Greece        189 cm  ...  Villeneuve d&apos;Ascq
# 1                 France        178 cm  ...  Villeneuve d&apos;Ascq
# 2                 France        173 cm  ...  Villeneuve d&apos;Ascq
# 3                 France        180 cm  ...  Villeneuve d&apos;Ascq
# 4               Portugal           NaN  ...  Villeneuve d&apos;Ascq
# ...                  ...           ...  ...                     ...
# 65875            Türkiye        187 cm  ...                 Akhisar
# 65876            Türkiye        189 cm  ...                 Akhisar
# 65877            Türkiye        183 cm  ...                 Akhisar
# 65878          Argentina           NaN  ...                 Akhisar
# 65879             Brazil        185 cm  ...                 Akhisar
#
#        venue_capacity venue_surface  \
# 0               50083         grass
# 1               50083         grass
# 2               50083         grass
# 3               50083         grass
# 4               50083         grass
# ...               ...           ...
# 65875           12139         grass
# 65876           12139         grass
# 65877           12139         grass
# 65878           12139         grass
# 65879           12139         grass
#
#                                              venue_image  league_name_y  \
# 0      https://media-2.api-sports.io/football/venues/...        Ligue 1
# 1      https://media-2.api-sports.io/football/venues/...        Ligue 1
# 2      https://media-2.api-sports.io/football/venues/...        Ligue 1
# 3      https://media-2.api-sports.io/football/venues/...        Ligue 1
# 4      https://media-2.api-sports.io/football/venues/...        Ligue 1
# ...                                                  ...            ...
# 65875  https://media-1.api-sports.io/football/venues/...      Süper Lig
# 65876  https://media-1.api-sports.io/football/venues/...      Süper Lig
# 65877  https://media-1.api-sports.io/football/venues/...      Süper Lig
# 65878  https://media-1.api-sports.io/football/venues/...      Süper Lig
# 65879  https://media-1.api-sports.io/football/venues/...      Süper Lig
#
#        league_type                                      league_logo_y  \
# 0           League  https://media-2.api-sports.io/football/leagues...
# 1           League  https://media-2.api-sports.io/football/leagues...
# 2           League  https://media-2.api-sports.io/football/leagues...
# 3           League  https://media-2.api-sports.io/football/leagues...
# 4           League  https://media-2.api-sports.io/football/leagues...
# ...            ...                                                ...
# 65875       League  https://media-3.api-sports.io/football/leagues...
# 65876       League  https://media-3.api-sports.io/football/leagues...
# 65877       League  https://media-3.api-sports.io/football/leagues...
# 65878       League  https://media-3.api-sports.io/football/leagues...
# 65879       League  https://media-3.api-sports.io/football/leagues...
#
#       country_name country_code                                country_flag
# 0           France           FR  https://media-2.api-sports.io/flags/fr.svg
# 1           France           FR  https://media-2.api-sports.io/flags/fr.svg
# 2           France           FR  https://media-2.api-sports.io/flags/fr.svg
# 3           France           FR  https://media-2.api-sports.io/flags/fr.svg
# 4           France           FR  https://media-2.api-sports.io/flags/fr.svg
# ...            ...          ...                                         ...
# 65875       Turkey           TR  https://media-2.api-sports.io/flags/tr.svg
# 65876       Turkey           TR  https://media-2.api-sports.io/flags/tr.svg
# 65877       Turkey           TR  https://media-2.api-sports.io/flags/tr.svg
# 65878       Turkey           TR  https://media-2.api-sports.io/flags/tr.svg
# 65879       Turkey           TR  https://media-2.api-sports.io/flags/tr.svg
#
# [65880 rows x 79 columns]

# %% [markdown]
# ## Define data frame for machine learning and analytics

# %% [markdown]
# ### Drop the fields not relevant to machine learning
# - **player_name, player_firstname, player_lastname** - 1 to 1 correlation with player_id
# - **player_birth_date** - 1 to 1 correlation with player_age

# %%
dfFootballCSV.iloc[:,7:].sample(5)
# Out:
#       player_birth_country player_nationality player_height player_weight  \
# 6130                  Mali               Mali        175 cm         75 kg
# 41197               Angola             Angola        180 cm         75 kg
# 12270            Australia          Australia        184 cm         80 kg
# 35752          Netherlands        Netherlands        174 cm         75 kg
# 27859                Italy              Italy        163 cm         59 kg
#
#        player_injured                                       player_photo  \
# 6130            False  https://media-3.api-sports.io/football/players...
# 41197           False  https://media-2.api-sports.io/football/players...
# 12270           False  https://media-2.api-sports.io/football/players...
# 35752           False  https://media-1.api-sports.io/football/players...
# 27859           False  https://media-1.api-sports.io/football/players...
#
#        league_id  season_id  team_id     team_name_x  ... venue_city  \
# 6130          61       2012     1305          Bastia  ...    Furiani
# 41197         94       2020      222        Boavista  ...      Porto
# 12270        144       2013      569  Club Brugge KV  ...     Brugge
# 35752         88       2018      200         Vitesse  ...     Arnhem
# 27859        135       2018      492          Napoli  ...     Napoli
#
#       venue_capacity venue_surface  \
# 6130           17000         grass
# 41197          28263         grass
# 12270          29062         grass
# 35752          25500         grass
# 27859          60240         grass
#
#                                              venue_image       league_name_y  \
# 6130   https://media-1.api-sports.io/football/venues/...             Ligue 1
# 41197  https://media-1.api-sports.io/football/venues/...       Primeira Liga
# 12270  https://media-2.api-sports.io/football/venues/...  Jupiler Pro League
# 35752  https://media-1.api-sports.io/football/venues/...          Eredivisie
# 27859  https://media-2.api-sports.io/football/venues/...             Serie A
#
#        league_type                                      league_logo_y  \
# 6130        League  https://media-2.api-sports.io/football/leagues...
# 41197       League  https://media-2.api-sports.io/football/leagues...
# 12270       League  https://media-3.api-sports.io/football/leagues...
# 35752       League  https://media-2.api-sports.io/football/leagues...
# 27859       League  https://media-1.api-sports.io/football/leagues...
#
#        country_name  country_code                                country_flag
# 6130         France            FR  https://media-2.api-sports.io/flags/fr.svg
# 41197      Portugal            PT  https://media-1.api-sports.io/flags/pt.svg
# 12270       Belgium            BE  https://media-3.api-sports.io/flags/be.svg
# 35752   Netherlands            NL  https://media-3.api-sports.io/flags/nl.svg
# 27859         Italy            IT  https://media-1.api-sports.io/flags/it.svg
#
# [5 rows x 72 columns]

# %%
dfFootballCSV['player_height'].value_counts()
# Out:
# 180 cm    4852
# 185 cm    4055
# 183 cm    3761
# 178 cm    3649
# 186 cm    3289
# 182 cm    3252
# 188 cm    3202
# 184 cm    3152
# 187 cm    3026
# 175 cm    3007
# 181 cm    2649
# 190 cm    2530
# 176 cm    2291
# 179 cm    2189
# 177 cm    2147
# 189 cm    1860
# 191 cm    1604
# 173 cm    1600
# 174 cm    1594
# 172 cm    1387
# 192 cm    1323
# 170 cm    1195
# 193 cm    1181
# 171 cm     787
# 194 cm     768
# 195 cm     583
# 196 cm     489
# 169 cm     451
# 168 cm     422
# 197 cm     254
# 167 cm     219
# 198 cm     192
# 165 cm     172
# 166 cm      99
# \n          84
# 199 cm      59
# 163 cm      56
# 201 cm      47
# 200 cm      33
# 164 cm      28
# 203 cm      23
# 162 cm      17
# 202 cm      16
# 160 cm      13
# 204 cm      12
# 208 cm       5
# 159 cm       2
# 161 cm       2
# 205 cm       2
# 158 cm       2
# 156 cm       2
# 157 cm       1
# Name: player_height, dtype: int64

# %%
dfFootballML = .drop(['player_name','player_firstname','player_lastname'], axis=1)
    ['team_national','team_logo','venue_address','venue_image','team_name','team_code',\
                           'venue_name','team_country'], axis=1)

 = .drop(['player_photo',,\
                               'player_birth_date'], axis=1)

 = dfFootballCSV.drop(['team_logo','team_name','league_name','league_country','league_logo',\
                                       'league_flag'], axis=1)

# %%
### Drop the fields not relevant to analysis

# %%
dfLeaguesA = .drop(['league_logo','country_flag','league_type','league_name'], axis=1)

 = .drop(['team_national','team_logo','venue_address','venue_image'], axis=1)

 = .drop(['player_photo','player_name','player_firstname','player_lastname'], axis=1)

 = dfFootballCSV.drop(['team_logo','team_name','league_name','league_country','league_logo','league_flag'], axis=1)

# %% [markdown]
# ## Duplicates

# %% [markdown]
# ## remove cm from player_height

# %% [markdown]
# ## remove kg from player_weight

# %% [markdown]
# ## Null values

# %% [markdown]
# ## Distribution of number of teams in leagues for all seasons
# It allows us to check if there are any issues with the data. The number of teams in any league and season should be between 10 and 25. The majority of leagues have 18-20 teams.

# %%
# Group by country and season
sns.displot(dfFootballCSV.groupby(['league_id','season_id'])['team_id'].nunique())\
    .set(xlabel='Number of teams', title='Distribution of the number of teams for all leagues/seasons')

# %% [markdown]
# The result is exactly as described above.

# %% [markdown]
# ## Distribution of players in teams

# %% [markdown]
# ## Distribution of players/teams in leagues

# %% [markdown]
# ## Distribution of players/teams/leagues in seasons

# %% [markdown]
# ## Check if venue_id is unique for each team_id, if majory yes then remove that field
# and venue_city vs venue_id

# %% [markdown]
# ## Remove players missing in teams

# %%
sql = '''
SELECT *
FROM dfPlayerStats 
WHERE team_id NOT IN (select team_id from dfTeams)
'''

sqldf(sql)
# Out:
#     team_id              team_name  \
# 0      9256  Olympique Lyonnais II
# 1      4715       Excelsior Virton
# 2      1353           Swindon Town
# 3      1342                Walsall
# 4      1353           Swindon Town
# 5       901                Partick
# 6       901                Partick
# 7       901                Partick
# 8       901                Partick
# 9       901                Partick
# 10      901                Partick
# 11      901                Partick
# 12      901                Partick
# 13      901                Partick
# 14      901                Partick
# 15      901                Partick
# 16      901                Partick
# 17      901                Partick
# 18      901                Partick
# 19     1353           Swindon Town
# 20      901                Partick
# 21      901                Partick
# 22     1342                Walsall
# 23     1342                Walsall
# 24      901                Partick
# 25     1695         Fidelis Andria
# 26      568       Sheriff Tiraspol
# 27     6496               Polessya
# 28     6523        Isparta 32 Spor
#
#                                             team_logo  league_id  \
# 0   https://media-2.api-sports.io/football/teams/9...         61
# 1   https://media-3.api-sports.io/football/teams/4...        144
# 2   https://media-2.api-sports.io/football/teams/1...         39
# 3   https://media-2.api-sports.io/football/teams/1...         39
# 4   https://media-1.api-sports.io/football/teams/1...         39
# 5   https://media-2.api-sports.io/football/teams/9...         39
# 6   https://media-2.api-sports.io/football/teams/9...         39
# 7   https://media-3.api-sports.io/football/teams/9...         39
# 8   https://media-3.api-sports.io/football/teams/9...         39
# 9   https://media-3.api-sports.io/football/teams/9...         39
# 10  https://media-2.api-sports.io/football/teams/9...         39
# 11  https://media-1.api-sports.io/football/teams/9...         39
# 12  https://media-2.api-sports.io/football/teams/9...         39
# 13  https://media-3.api-sports.io/football/teams/9...         39
# 14  https://media-3.api-sports.io/football/teams/9...         39
# 15  https://media-1.api-sports.io/football/teams/9...         39
# 16  https://media-2.api-sports.io/football/teams/9...         39
# 17  https://media-3.api-sports.io/football/teams/9...         39
# 18  https://media-2.api-sports.io/football/teams/9...         39
# 19  https://media-2.api-sports.io/football/teams/1...         39
# 20  https://media-3.api-sports.io/football/teams/9...         39
# 21  https://media-2.api-sports.io/football/teams/9...         39
# 22  https://media-1.api-sports.io/football/teams/1...         39
# 23  https://media-3.api-sports.io/football/teams/1...         39
# 24  https://media-1.api-sports.io/football/teams/9...         39
# 25  https://media-1.api-sports.io/football/teams/1...        135
# 26  https://media-3.api-sports.io/football/teams/5...        333
# 27  https://media-3.api-sports.io/football/teams/6...        333
# 28  https://media-1.api-sports.io/football/teams/6...        203
#
#            league_name league_country  \
# 0              Ligue 1         France
# 1   Jupiler Pro League        Belgium
# 2       Premier League        England
# 3       Premier League        England
# 4       Premier League        England
# 5       Premier League        England
# 6       Premier League        England
# 7       Premier League        England
# 8       Premier League        England
# 9       Premier League        England
# 10      Premier League        England
# 11      Premier League        England
# 12      Premier League        England
# 13      Premier League        England
# 14      Premier League        England
# 15      Premier League        England
# 16      Premier League        England
# 17      Premier League        England
# 18      Premier League        England
# 19      Premier League        England
# 20      Premier League        England
# 21      Premier League        England
# 22      Premier League        England
# 23      Premier League        England
# 24      Premier League        England
# 25             Serie A          Italy
# 26      Premier League        Ukraine
# 27      Premier League        Ukraine
# 28           Süper Lig         Turkey
#
#                                           league_logo  \
# 0   https://media-3.api-sports.io/football/leagues...
# 1   https://media-2.api-sports.io/football/leagues...
# 2   https://media-3.api-sports.io/football/leagues...
# 3   https://media-3.api-sports.io/football/leagues...
# 4   https://media-1.api-sports.io/football/leagues...
# 5   https://media-2.api-sports.io/football/leagues...
# 6   https://media-2.api-sports.io/football/leagues...
# 7   https://media-3.api-sports.io/football/leagues...
# 8   https://media-2.api-sports.io/football/leagues...
# 9   https://media-1.api-sports.io/football/leagues...
# 10  https://media-2.api-sports.io/football/leagues...
# 11  https://media-1.api-sports.io/football/leagues...
# 12  https://media-1.api-sports.io/football/leagues...
# 13  https://media-2.api-sports.io/football/leagues...
# 14  https://media-2.api-sports.io/football/leagues...
# 15  https://media-1.api-sports.io/football/leagues...
# 16  https://media-2.api-sports.io/football/leagues...
# 17  https://media-2.api-sports.io/football/leagues...
# 18  https://media-3.api-sports.io/football/leagues...
# 19  https://media-2.api-sports.io/football/leagues...
# 20  https://media-3.api-sports.io/football/leagues...
# 21  https://media-3.api-sports.io/football/leagues...
# 22  https://media-2.api-sports.io/football/leagues...
# 23  https://media-3.api-sports.io/football/leagues...
# 24  https://media-1.api-sports.io/football/leagues...
# 25  https://media-2.api-sports.io/football/leagues...
# 26  https://media-3.api-sports.io/football/leagues...
# 27  https://media-1.api-sports.io/football/leagues...
# 28  https://media-3.api-sports.io/football/leagues...
#
#                                    league_flag  league_season  \
# 0   https://media-2.api-sports.io/flags/fr.svg           2021
# 1   https://media-3.api-sports.io/flags/be.svg           2021
# 2   https://media-2.api-sports.io/flags/gb.svg           2021
# 3   https://media-3.api-sports.io/flags/gb.svg           2021
# 4   https://media-1.api-sports.io/flags/gb.svg           2021
# 5   https://media-3.api-sports.io/flags/gb.svg           2021
# 6   https://media-3.api-sports.io/flags/gb.svg           2021
# 7   https://media-2.api-sports.io/flags/gb.svg           2021
# 8   https://media-2.api-sports.io/flags/gb.svg           2021
# 9   https://media-3.api-sports.io/flags/gb.svg           2021
# 10  https://media-3.api-sports.io/flags/gb.svg           2021
# 11  https://media-2.api-sports.io/flags/gb.svg           2021
# 12  https://media-3.api-sports.io/flags/gb.svg           2021
# 13  https://media-1.api-sports.io/flags/gb.svg           2021
# 14  https://media-1.api-sports.io/flags/gb.svg           2021
# 15  https://media-3.api-sports.io/flags/gb.svg           2021
# 16  https://media-1.api-sports.io/flags/gb.svg           2021
# 17  https://media-2.api-sports.io/flags/gb.svg           2021
# 18  https://media-1.api-sports.io/flags/gb.svg           2021
# 19  https://media-1.api-sports.io/flags/gb.svg           2021
# 20  https://media-2.api-sports.io/flags/gb.svg           2021
# 21  https://media-3.api-sports.io/flags/gb.svg           2021
# 22  https://media-3.api-sports.io/flags/gb.svg           2021
# 23  https://media-1.api-sports.io/flags/gb.svg           2021
# 24  https://media-3.api-sports.io/flags/gb.svg           2021
# 25  https://media-3.api-sports.io/flags/it.svg           2021
# 26  https://media-1.api-sports.io/flags/ua.svg           2021
# 27  https://media-2.api-sports.io/flags/ua.svg           2021
# 28  https://media-3.api-sports.io/flags/tr.svg           2021
#
#     games_appearences  ...  cards_yellowred  cards_red penalty_won  \
# 0                 0.0  ...              0.0        0.0        None
# 1                 0.0  ...              0.0        0.0        None
# 2                 0.0  ...              0.0        0.0        None
# 3                 0.0  ...              0.0        0.0        None
# 4                 0.0  ...              0.0        0.0        None
# 5                 0.0  ...              0.0        0.0        None
# 6                 0.0  ...              0.0        0.0        None
# 7                 0.0  ...              0.0        0.0        None
# 8                 0.0  ...              0.0        0.0        None
# 9                 0.0  ...              0.0        0.0        None
# 10                0.0  ...              0.0        0.0        None
# 11                0.0  ...              0.0        0.0        None
# 12                0.0  ...              0.0        0.0        None
# 13                0.0  ...              0.0        0.0        None
# 14                0.0  ...              0.0        0.0        None
# 15                0.0  ...              0.0        0.0        None
# 16                0.0  ...              0.0        0.0        None
# 17                0.0  ...              0.0        0.0        None
# 18                0.0  ...              0.0        0.0        None
# 19                0.0  ...              0.0        0.0        None
# 20                0.0  ...              0.0        0.0        None
# 21                0.0  ...              0.0        0.0        None
# 22                0.0  ...              0.0        0.0        None
# 23                0.0  ...              0.0        0.0        None
# 24                0.0  ...              0.0        0.0        None
# 25                0.0  ...              0.0        0.0        None
# 26                0.0  ...              0.0        0.0        None
# 27                0.0  ...              0.0        0.0        None
# 28                0.0  ...              0.0        0.0        None
#
#    penalty_commited penalty_scored  penalty_missed  penalty_saved  player_id  \
# 0              None           None            None           None        670
# 1              None           None            None           None     163034
# 2              None           None            None           None      17968
# 3              None           None            None           None     157025
# 4              None           None            None           None     348463
# 5              None           None            None           None       1735
# 6              None           None            None           None      15430
# 7              None           None            None           None      20220
# 8              None           None            None           None      45204
# 9              None           None            None           None      45285
# 10             None           None            None           None     108555
# 11             None           None            None           None      20328
# 12             None           None            None           None      44953
# 13             None           None            None           None      45117
# 14             None           None            None           None      45163
# 15             None           None            None           None      45164
# 16             None           None            None           None      45213
# 17             None           None            None           None      45309
# 18             None           None            None           None      45325
# 19             None           None            None           None     270139
# 20             None           None            None           None     280963
# 21             None           None            None           None     125695
# 22             None           None            None           None      17463
# 23             None           None            None           None     348461
# 24             None           None            None           None      45013
# 25             None           None            None           None      31395
# 26             None           None            None           None      63478
# 27             None           None            None           None      63425
# 28             None           None            None           None     180755
#
#     league_id.1 season_id
# 0            61      2021
# 1           144      2021
# 2            39      2021
# 3            39      2021
# 4            39      2021
# 5            39      2021
# 6            39      2021
# 7            39      2021
# 8            39      2021
# 9            39      2021
# 10           39      2021
# 11           39      2021
# 12           39      2021
# 13           39      2021
# 14           39      2021
# 15           39      2021
# 16           39      2021
# 17           39      2021
# 18           39      2021
# 19           39      2021
# 20           39      2021
# 21           39      2021
# 22           39      2021
# 23           39      2021
# 24           39      2021
# 25          135      2021
# 26          333      2021
# 27          333      2021
# 28          203      2021
#
# [29 rows x 49 columns]

# %% [markdown]
# ## The same players in players and player_stats

# %%
sql = '''
SELECT COUNT(DISTINCT player_id) "Number of players", 'Players' source
FROM dfPlayers 
UNION ALL
SELECT COUNT(DISTINCT player_id) "Number of players", 'Player stats' source
FROM dfPlayerStats
'''

sqldf(sql)
# Out:
#    Number of players        source
# 0               7123       Players
# 1               7123  Player stats

# %% [markdown]
# ## Remove highly correlated features

# %% [markdown]
# ## remove player_birth_date as there is age

# %%
## Add the same set of features but for the team

# %% [markdown]
# # Other

# %%
sql = '''
select distinct team_id
from dfFootball 
'''

sql = '''
select distinct player_birth_country
from dfPlayersCSV 
'''



sqldf(sql)
# Out:
#     player_birth_country
# 0                 Greece
# 1                 France
# 2                   Mali
# 3                 Brazil
# 4               Cameroon
# ..                   ...
# 169   Bosnia-Herzegovina
# 170       CÃ´te d'Ivoire
# 171           Montserrat
# 172            St. Lucia
# 173       Chinese Taipei
#
# [174 rows x 1 columns]
